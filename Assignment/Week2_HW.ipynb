# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanardo/DATA201-labs/blob/main/Assignment/Week2_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Questions 8 (p. 65), 9 (p. 66), and 10 (p. 67)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # QUESTION 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## a)

# %%
college = pd.read_csv("/content/drive/MyDrive/data 201/Datasets/College.csv")

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   777 non-null    object
#  1   Private      777 non-null    object
#  2   Apps         777 non-null    int64
#  3   Accept       777 non-null    int64
#  4   Enroll       777 non-null    int64
#  5   Top10perc    777 non-null    int64
#  6   Top25perc    777 non-null    int64
#  7   F.Undergrad  777 non-null    int64
#  8   P.Undergrad  777 non-null    int64
#  9   Outstate     777 non-null    int64
#  10  Room.Board   777 non-null    int64
#  11  Books        777 non-null    int64
#  12  Personal     777 non-null    int64
#  13  PhD          777 non-null    int64
#  14  Terminal     777 non-null    int64
#  15  S.F.Ratio    777 non-null    float64
#  16  perc.alumni  777 non-null    int64
#  17  Expend       777 non-null    int64
#  18  Grad.Rate    777 non-null    int64
# ...

# %% [markdown]
# ## b)

# %%
college2 = pd.read_csv("/content/drive/MyDrive/data 201/Datasets/College.csv",index_col=0)
college3 = college.rename({"Unnamed: 0":"College"},
                          axis=1)
college3 = college3.set_index("College")

# %%
college = college3
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# ## c)

# %%
college3.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## d)

# %%
A = ["Top10perc","Apps","Enroll"]
pd.plotting.scatter_matrix(college3[A]);

# %% [markdown]
# ## e)

# %%
college.boxplot("Outstate", by = "Private");

# %% [markdown]
# ## f)

# %%
college["Elite"] = pd.cut(college["Top10perc"],
                          [0,50,100],
                          labels=["No","Yes"])
college.value_counts(college["Elite"])
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot("Outstate", by = "Elite");

# %% [markdown]
# ## g)

# %%
fig, ax = plt.subplots(2,2,figsize=(16,8))
college.hist("Outstate", bins=12, ax=ax[0,0])
college.hist("Apps", bins=12, ax=ax[0,1])
college.hist("Enroll", bins=12, ax=ax[1,0])
college.hist("Accept", bins=12, ax=ax[1,1]);

# %% [markdown]
# ## h)
# The graph below shows whether higher instructional expenditure per student is associated with a higher percentage of new students from the top 10% of their high school class.

# %%
college.plot.scatter("Expend","Top10perc")
plt.title("Instructional Expenditure versus Top 10% Students");

# %% [markdown]
# # QUESTION 9

# %%
Auto = pd.read_csv("/content/drive/MyDrive/data 201/Datasets/Auto.csv",
                   na_values=['?'])

# %%
Auto.shape
# Out:
# (397, 9)

# %%
Auto_new = Auto.dropna()
Auto_new.shape
# Out:
# (392, 9)

# %%
Auto=Auto_new
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 30.6+ KB

# %% [markdown]
# ## a)
# Quantitative: mpg, displacement, horsepower, weight, acceleration
#
# Qualitative:cylinders, year, origin, name

# %% [markdown]
# ## b)

# %%
Auto_quantitative = Auto[["mpg", "displacement", "horsepower", "weight", "acceleration"]]
Auto_quantitative.min(), Auto_quantitative.max()
# Out:
# (mpg                9.0
#  displacement      68.0
#  horsepower        46.0
#  weight          1613.0
#  acceleration       8.0
#  dtype: float64,
#  mpg               46.6
#  displacement     455.0
#  horsepower       230.0
#  weight          5140.0
#  acceleration      24.8
#  dtype: float64)

# %%
Auto_quantitative_range = Auto_quantitative.max() - Auto_quantitative.min()
print(Auto_quantitative_range)
# Out:
# mpg               37.6
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# dtype: float64

# %% [markdown]
# ## c)

# %%
Auto_quantitative.mean()
# Out:
# mpg               23.515869
# displacement     193.532746
# horsepower       104.469388
# weight          2970.261965
# acceleration      15.555668
# dtype: float64

# %%
Auto_quantitative.std()
# Out:
# mpg               7.825804
# displacement    104.379583
# horsepower       38.491160
# weight          847.904119
# acceleration      2.749995
# dtype: float64

# %% [markdown]
# ## d)

# %%
Auto_selected = Auto_quantitative.drop(Auto_quantitative.index[9:85])
Auto_selected.std(), Auto_selected.mean(), (Auto_selected.max() - Auto_selected.min())
# Out:
# (mpg               7.908184
#  displacement     99.635385
#  horsepower       35.895567
#  weight          810.642938
#  acceleration      2.680514
#  dtype: float64,
#  mpg               24.438629
#  displacement     187.049844
#  horsepower       100.955836
#  weight          2933.962617
#  acceleration      15.723053
#  dtype: float64,
#  mpg               35.6
#  displacement     387.0
#  horsepower       184.0
#  weight          3348.0
#  acceleration      16.3
#  dtype: float64)

# %% [markdown]
# ## e)
# The graph below shows that the variables displacemnt, horsepower and weight have a inverse relation with the variable MPG, meaning that if the engine displacement, engine horsepower and vehicle weight (lbs.) increase, miles per gallon will decrase.

# %%
pd.plotting.scatter_matrix(Auto, figsize=(12,12));

# %% [markdown]
# ##f)
# If we compare the MPG versus years, it is clear that as the years go by, fuel consumption decrease. Cars get more mile per gallon.

# %% [markdown]
# # Question 10

# %% [markdown]
# ## a)

# %%
boston = pd.read_csv("/content/drive/MyDrive/data 201/Datasets/Boston.csv")

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  lstat       506 non-null    float64
#  13  medv        506 non-null    float64
# dtypes: float64(10), int64(4)
# memory usage: 55.5 KB

# %% [markdown]
# ## b)
# This is a dataset called "Boston" that contains 506 rows for each suburbs of Boston. There are 13 columns containing variables, in which those variables have information about housing values.

# %% [markdown]
# ## c)

# %%
pd.plotting.scatter_matrix(boston, figsize=(12,12));

# %% [markdown]
# ## d)
# Crime rate is strongly positively associated with rad and tax, and negatively associated with medv and dis; chas shows no relationship.

# %%
corr_crim = boston.corr()["crim"].drop("crim").sort_values()
print(corr_crim)
# Out:
# medv         -0.388305
# dis          -0.379670
# rm           -0.219247
# zn           -0.200469
# chas         -0.055892
# ptratio       0.289946
# age           0.352734
# indus         0.406583
# Unnamed: 0    0.407407
# nox           0.420972
# lstat         0.455621
# tax           0.582764
# rad           0.625505
# Name: crim, dtype: float64

# %% [markdown]
# ## e)

# %%
print(boston[["crim", "tax", "ptratio"]].describe())
print(boston.nlargest(5, "crim")[["crim", "tax", "ptratio"]])
print(boston.nlargest(5, "tax")[["crim", "tax", "ptratio"]])
print(boston.nlargest(5, "ptratio")[["crim", "tax", "ptratio"]])
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000
#         crim  tax  ptratio
# 380  88.9762  666     20.2
# 418  73.5341  666     20.2
# 405  67.9208  666     20.2
# 410  51.1358  666     20.2
# 414  45.7461  666     20.2
#         crim  tax  ptratio
# 488  0.15086  711     20.1
# 489  0.18337  711     20.1
# 490  0.20746  711     20.1
# 491  0.10574  711     20.1
# 492  0.11132  711     20.1
#         crim  tax  ptratio
# 354  0.04301  334     22.0
# 355  0.10659  334     22.0
# 127  0.25915  437     21.2
# 128  0.32543  437     21.2
# 129  0.88125  437     21.2

# %% [markdown]
# ## f)

# %%
boston["chas"].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
x = boston[boston["chas"]==1].shape[0]

print(f" Quantity of suburbs bound the Charles river: {x}")
# Out:
#  Quantity of suburbs bound the Charles river: 35

# %% [markdown]
# ## g)

# %%
x = boston["ptratio"].median()

print(f" pupil-teacher ratio: {x:.2f}")
# Out:
#  pupil-teacher ratio: 19.05

# %% [markdown]
# ## h)
# Compared with the overall ranges, the lowest median value of owner-occupied homes has a much higher crime rate, older housing, industrial land proportion, tax rate, and LSTAT. It also has fewer rooms per dwelling and a lower median home value. Overall, this observation differs significantly from the average, particularly in terms of crime, housing conditions, and property value.

# %%
boston.sort_values(by="medv", ascending=True)
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 398         399  38.35180   0.0  18.10     0  0.693  5.453  100.0  1.4896
# 405         406  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254
# 400         401  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888
# 399         400   9.91655   0.0  18.10     0  0.693  5.852   77.8  1.5004
# 414         415  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 163         164   1.51902   0.0  19.58     1  0.605  8.375   93.9  2.1620
# 166         167   2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459
# 162         163   1.83377   0.0  19.58     1  0.605  7.802   98.2  2.0407
# 161         162   1.46336   0.0  19.58     0  0.605  7.489   90.8  1.9709
# 195         196   0.01381  80.0   0.46     0  0.422  7.875   32.0  5.6484
#
#      rad  tax  ptratio  lstat  medv
# 398   24  666     20.2  30.59   5.0
# ...

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# ## i)
# The only 13 suburbs that average more than eight rooms per dwelling has a significant lower crime rate (0.72 vs. 3.61), lower taxes (325.08 vs. 408.24), lower LSTAT (4.31 vs. 12.65), and a higher median home value (44.20 vs. 22.53). Overall, the sample represent areas with larger homes, lower crime, and higher property values than the full dataset.

# %%
boston[(boston["rm"]>=7)].shape[0]
# Out:
# 64

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston[(boston["rm"]>=8)].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...
